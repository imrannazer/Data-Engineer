# %% [markdown]
# # DataFrame in Pyspark

# %% [markdown]
# ## 1. Create DF using RDD (toDF())

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2.Create DF using RDD (toDF()) with User define Schema

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 3. Spark inferschema

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. schema by using StructType and StructField

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. user define Schema by using string

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 6. user define schema by using StructType and add( )

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 7. TSV

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 8. PARQUET

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 9. ORC

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 10. AVRO

# %% [markdown]
# ## 11. JSON

# %% [markdown]
# ## 12.CSV
